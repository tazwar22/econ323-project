# %% [markdown]
# # Sentiment Analysis

# %%
#Imports
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Data paths
datadir = os.path.join(os.getcwd(), 'archive')

data_map = {
"customers" : os.path.join(datadir, 'olist_customers_dataset.csv'),
"geolocation" : os.path.join(datadir, 'olist_geolocation_dataset.csv'),
#Orders
"order_items" : os.path.join(datadir, 'olist_order_items_dataset.csv'),
"order_payments" : os.path.join(datadir, 'olist_order_payments_dataset.csv'),
"order_reviews" : os.path.join(datadir, 'olist_order_reviews_dataset.csv'),
# MAIN DATA
"orders" : os.path.join(datadir, 'olist_orders_dataset.csv'),
#Products
"products" : os.path.join(datadir, 'olist_products_dataset.csv'),
"sellers" : os.path.join(datadir, 'olist_sellers_dataset.csv'),
"prod2cat_translation" : os.path.join(datadir, 'product_category_name_translation.csv')
}

def load(df_name):
    return pd.read_csv(data_map[df_name])

# %%
reviews = load('order_reviews')
reviews = reviews.loc[(~reviews.review_comment_message.isnull()) & (~reviews.review_score.isnull())]
reviews
# Out:
#                               review_id                          order_id  \
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 9      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12     4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 15     3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# ...                                 ...                               ...
# 99205  98fffa80dc9acbde7388bef1600f3b15  d398e9c82363c12527f71801bf0e6100
# 99208  df5fae90e85354241d5d64a8955b2b09  509b86c65fe4e2ad5b96408cfef9755e
# 99215  a709d176f59bc3af77f4149c96bae357  d5cb12269711bd1eaf7eed8fd32a7c95
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 3                 5                  NaN
# 4                 5                  NaN
# 9                 4            recomendo
# 12                4                  NaN
# 15                5      Super recomendo
# ...             ...                  ...
# 99205             4                  NaN
# 99208             5                  NaN
# 99215             3                  NaN
# 99221             5                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 9      aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 12       Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 15     Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ...                                                  ...                  ...
# 99205  para este produto recebi de acordo com a compr...  2017-11-29 00:00:00
# 99208  Entregou dentro do prazo. O produto chegou em ...  2018-02-07 00:00:00
# 99215  O produto não foi enviado com NF, não existe v...  2018-05-19 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# 9         2018-05-23 16:45:47
# 12        2018-02-20 10:52:22
# 15        2018-05-24 03:00:01
# ...                       ...
# 99205     2017-11-30 15:52:51
# 99208     2018-02-19 19:47:23
# 99215     2018-05-20 21:51:06
# 99221     2018-03-23 09:10:43
# 99223     2017-07-03 21:01:49
#
# [40977 rows x 7 columns]

# %% [markdown]
# '''
# https://stackabuse.com/text-translation-with-google-translate-api-in-python/
# '''
# # import googletrans
# # from googletrans import Translator
#
# from google_trans_new import google_translator
# translator = google_translator()
#
# # translator = Translator(service_urls=['translate.googleapis.com'])

# %%
from translate import Translator
translator = Translator(from_lang='pt', to_lang="en")
translator.translate(reviews.review_comment_message.values[100])
# Out:
# 'my product has not arrived... according to the trace is paraded in Ribeirão Preto sp...'

# %%
def translate(rev):
    return translator.translate(rev)

reviews['translated_review'] = reviews['review_comment_message'].apply(translate)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-da3164fd5d44> in <module>
#       2     return translator.translate(rev)
#       3
# ----> 4 reviews['translated_review'] = reviews['review_comment_message'].apply(translate)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-37-da3164fd5d44> in translate(rev)
#       1 def translate(rev):
# ----> 2     return translator.translate(rev)
#       3
#       4 reviews['translated_review'] = reviews['review_comment_message'].apply(translate)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/translate/translate.py in translate(self, text)
#      43
#      44         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 45         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/translate/translate.py in <genexpr>(.0)
#      43
#      44         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 45         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/translate/providers/mymemory_translated.py in get_translation(self, text)
#      40
#      41     def get_translation(self, text):
# ---> 42         data = self._make_request(text)
#      43
#      44         translation = data['responseData']['translatedText']
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/translate/providers/mymemory_translated.py in _make_request(self, text)
#      36             params['de'] = self.email
#      37
# ---> 38         response = requests.get(self.base_url, params=params, headers=self.headers)
#      39         return response.json()
#      40
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     decode_content=False,
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#     452
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/py3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
translated = []
for i, row in reviews.iterrows():
    print(translator.translate(row['review_comment_message']))
    if i == 9:
        break
# Out:
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  09 HOURS 14 MINUTES 48 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  09 HOURS 14 MINUTES 47 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  09 HOURS 14 MINUTES 47 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
